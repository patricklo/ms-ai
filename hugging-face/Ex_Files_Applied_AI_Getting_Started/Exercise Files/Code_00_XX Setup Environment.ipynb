# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip install tensorflow
# !pip install torch
# !pip install keras
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.17.0
# Collecting torch
#   Using cached torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from torch) (4.11.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from torch) (3.1.4)
# Collecting fsspec (from torch)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from jinja2->torch) (2.1.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached torch-2.4.0-cp312-cp312-win_amd64.whl (197.8 MB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch
# Successfully installed filelock-3.15.4 fsspec-2024.6.1 mpmath-1.3.0 networkx-3.3 sympy-1.13.2 torch-2.4.0
# Requirement already satisfied: keras in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (3.5.0)
# Requirement already satisfied: absl-py in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (13.8.0)
# Requirement already satisfied: namex in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Collecting transformers
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from transformers) (3.15.4)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Using cached huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.7.24-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from transformers) (2.32.3)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.4.4-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests->transformers) (2024.7.4)
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------------ --------------------- 4.5/9.5 MB 24.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 24.5 MB/s eta 0:00:00
# Using cached huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Using cached regex-2024.7.24-cp312-cp312-win_amd64.whl (269 kB)
# Using cached safetensors-0.4.4-cp312-none-win_amd64.whl (286 kB)
# Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.24.6 regex-2024.7.24 safetensors-0.4.4 tokenizers-0.19.1 tqdm-4.66.5 transformers-4.44.2
# Collecting datasets
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-17.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.32.2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Collecting aiohttp (from datasets)
#   Using cached aiohttp-3.10.5-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets) (6.0.1)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Using cached aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Using cached multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.6-cp312-cp312-win_amd64.whl.metadata (39 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from pandas->datasets) (2024.1)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ---------------------------------------- 0.0/527.3 kB ? eta -:--:--
#    ---------------------------------------- 527.3/527.3 kB 8.6 MB/s eta 0:00:00
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached aiohttp-3.10.5-cp312-cp312-win_amd64.whl (377 kB)
# Using cached pyarrow-17.0.0-cp312-cp312-win_amd64.whl (25.1 MB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Using cached aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
# Using cached multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading yarl-1.9.6-cp312-cp312-win_amd64.whl (78 kB)
# Installing collected packages: xxhash, tzdata, pyarrow, multidict, frozenlist, dill, aiohappyeyeballs, yarl, pandas, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 datasets-2.21.0 dill-0.3.8 frozenlist-1.4.1 multidict-6.0.5 multiprocess-0.70.16 pandas-2.2.2 pyarrow-17.0.0 tzdata-2024.1 xxhash-3.5.0 yarl-1.9.6
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/992.0 kB ? eta -:--:--
#    --------------------------------------- 992.0/992.0 kB 23.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (2.21.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (0.24.6)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets>=2.0.0->evaluate) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from requests>=2.19.0->evaluate) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.6)
# Requirement already satisfied: six>=1.5 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.2
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.4.2 nltk-3.9.1
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: absl-py in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rouge_score) (2.1.0)
# Requirement already satisfied: nltk in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from nltk->rouge_score) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from nltk->rouge_score) (4.66.5)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-1\lib\site-packages (from click->nltk->rouge_score) (0.4.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py): started
#   Building wheel for rouge_score (setup.py): finished with status 'done'
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24972 sha256=d9bbf4f22c950e8d73c640fd8353cc8b4d0e10537814cc1f66c357e8f73440f9
#   Stored in directory: c:\users\patrick\appdata\local\pip\cache\wheels\85\9d\af\01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Collecting pytz>=2020.1
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pytz, xxhash, pyarrow, multidict, fsspec, frozenlist, dill, async-timeout, yarl, responses, pandas, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.3 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.7.1 dill-0.3.6 frozenlist-1.3.3 fsspec-2022.11.0 multidict-6.0.3 multiprocess-0.70.14 pandas-1.5.2 pyarrow-10.0.1 pytz-2022.6 responses-0.18.0 xxhash-3.1.0 yarl-1.8.2
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Collecting evaluate
#   Downloading evaluate-0.3.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (1.5.2)
# Requirement already satisfied: dill in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (1.23.5)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (4.64.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (2.28.1)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (3.1.0)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.11.1)
# Requirement already satisfied: responses<0.19 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (21.3)
# Requirement already satisfied: datasets>=2.0.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (2.7.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (10.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2022.9.24)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from pandas->evaluate) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.3.0
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk) (4.64.1)
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk) (2022.10.31)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.3 joblib-1.2.0 nltk-3.7
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (1.3.0)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (3.7)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (1.2.0)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24936 sha256=9bac8b69a2728f68ba497190deeda8c210b92ea21df29eb3b31d6d2e1e5253ed
#   Stored in directory: /Users/linkedin/Library/Caches/pip/wheels/9b/3d/39/09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
