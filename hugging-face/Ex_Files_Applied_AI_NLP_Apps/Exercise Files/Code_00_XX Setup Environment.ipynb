# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip3 install tensorflow===2.10.0
# !pip3 install torch
# !pip3 install keras===2.10.0
# !pip3 install transformers
# !pip3 install datasets
# !pip3 install sentencepiece
# !pip3 install evaluate
# !pip3 install nltk
# !pip3 install rouge_score
# !pip3 install pytorch
# Out:
# Requirement already satisfied: tensorflow===2.10.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (2.0.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (24.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (1.66.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorflow===2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from astunparse>=1.6.0->tensorflow===2.10.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.34.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.2.2)
# Requirement already satisfied: torch in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (2.4.1)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from torch) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: keras===2.10.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (2.10.0)
# Requirement already satisfied: transformers in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (4.44.2)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: datasets in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (2.21.0)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (3.16.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: sentencepiece in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (0.2.0)
# Requirement already satisfied: evaluate in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (0.4.2)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (2.21.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (0.24.6)
# Requirement already satisfied: packaging in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.16.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.11.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: nltk in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: rouge_score in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (0.1.2)
# Requirement already satisfied: absl-py in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from rouge_score) (2.1.0)
# Requirement already satisfied: nltk in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk->rouge_score) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from nltk->rouge_score) (4.66.5)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\envs\transformer-3\lib\site-packages (from click->nltk->rouge_score) (0.4.6)
# Collecting pytorch
#   Downloading pytorch-1.0.2.tar.gz (689 bytes)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pytorch
#   Building wheel for pytorch (setup.py): started
#   Building wheel for pytorch (setup.py): finished with status 'error'
#   Running setup.py clean for pytorch
# Failed to build pytorch
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\patrick\AppData\Local\Temp\pip-install-mc5gb39l\pytorch_a39d1701051b4c6e9fbfe4f543983130\setup.py", line 15, in <module>
#       raise Exception(message)
#   Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pytorch)
